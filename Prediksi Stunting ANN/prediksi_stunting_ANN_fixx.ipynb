# %% [markdown]
# # **PREDIKSI STUNTING**

# %% [markdown]
# #**1. LOAD DATA**

# %% [markdown]
# From this dataset, we analysed and built a prediction model to determine whether someone has a risk of stunting or not.

# %%
# Load library yang diperlukan
import pandas as pd

# %%
# Muat data dari Google Sheets
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1bP7kO-Duv-wTeQN-Vzi39W-HVLDy6BmM/export?format=csv')

# %%
# Display data
df
# Out:
#          IDRT   IDART  W_ruta W_balita    PSU  STRATA  B1R1  provkab  B1R5  \
# 0      114171  303853  119,90   276,73  12800   33012    33     3301     2
# 1      114172   78611  119,90   261,41  12800   33012    33     3301     2
# 2      114173   28591  119,90   276,73  12800   33012    33     3301     2
# 3      114174   56051  119,90   261,41  12800   33012    33     3301     2
# 4      114174   54411  119,90   261,41  12800   33012    33     3301     2
# ...       ...     ...     ...      ...    ...     ...   ...      ...   ...
# 25795  138963  265605   29,42    29,52  15348   33761    33     3376     1
# 25796  138964    1692   29,42    29,32  15348   33761    33     3376     1
# 25797  138965  252316   29,42    29,52  15348   33761    33     3376     1
# 25798  138966  188592   29,42    29,32  15348   33761    33     3376     1
# 25799  138967  295429   29,42    29,52  15348   33761    33     3376     1
#
#        NART  ... B4K9_ayah B4K10_ayah  B4K11_ayah    HAZ    WAZ    WHZ  \
# 0       4.0  ...       5.0        0.0         1.0  -2,60  -1,63   0,00
# 1       4.0  ...       5.0        0.0        32.0  -0,48  -1,59  -1,84
# 2       4.0  ...       5.0        0.0        32.0  -0,02   0,93   1,30
# 3       6.0  ...       9.0        0.0         2.0  -2,52   0,28   2,02
# 4       5.0  ...       9.0        0.0         2.0  -2,31  -1,10   0,09
# ...     ...  ...       ...        ...         ...    ...    ...    ...
# 25795   6.0  ...       7.0        0.0         1.0  -1,67  -1,43  -0,63
# 25796   3.0  ...       8.0        0.0         1.0   0,92  -0,11  -1,72
# 25797   3.0  ...       8.0        0.0         1.0  -2,05  -1,97  -1,15
# 25798   5.0  ...       8.0        0.0        32.0  -1,11  -1,68  -1,54
# 25799   5.0  ...       9.0        0.0         1.0  -0,65  -0,32   0,10
#
#        stunting  underweight wasting overweight
# 0          1,00         2,00    2,00       2,00
# 1          2,00         2,00    2,00       2,00
# 2          2,00         2,00    2,00       2,00
# 3          1,00         2,00    2,00       1,00
# 4          1,00         2,00    2,00       2,00
# ...         ...          ...     ...        ...
# 25795      2,00         2,00    2,00       2,00
# 25796      2,00         2,00    2,00       2,00
# 25797      1,00         2,00    2,00       2,00
# 25798      2,00         2,00    2,00       2,00
# 25799      2,00         2,00    2,00       2,00
#
# [25800 rows x 67 columns]

# %% [markdown]
# #**2. EDA**

# %%
# Display an information of the dataset file
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25800 entries, 0 to 25799
# Data columns (total 67 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   IDRT          25800 non-null  int64
#  1   IDART         25800 non-null  int64
#  2   W_ruta        25800 non-null  object
#  3   W_balita      25800 non-null  object
#  4   PSU           25800 non-null  int64
#  5   STRATA        25800 non-null  int64
#  6   B1R1          25800 non-null  int64
#  7   provkab       25800 non-null  int64
#  8   B1R5          25800 non-null  int64
#  9   NART          25798 non-null  float64
#  10  PTEKS         25800 non-null  object
#  11  KBTEKS        25800 non-null  object
#  12  B4K3          25800 non-null  int64
#  13  B4K4          25800 non-null  int64
#  14  b4k7hr        25800 non-null  int64
#  15  b4k7bln       25800 non-null  int64
#  16  I01           25792 non-null  float64
#  17  I04           25349 non-null  float64
#  18  BB8R3         19423 non-null  object
#  19  I05A          25568 non-null  object
#  20  I05B          25560 non-null  object
#  21  I07           25800 non-null  object
#  22  I08           24101 non-null  object
#  23  I09           5960 non-null   float64
#  24  I10           23436 non-null  object
#  25  BB8R9         16914 non-null  float64
#  26  J01A          25798 non-null  float64
#  27  J01B          25794 non-null  float64
#  28  J01C          25800 non-null  object
#  29  J02A          25800 non-null  int64
#  30  J02B          25800 non-null  object
#  31  J02C          25800 non-null  int64
#  32  B4K1_ibu      25149 non-null  float64
#  33  B4K3_ibu      25149 non-null  float64
#  34  B4K4_ibu      25149 non-null  float64
#  35  B4K5_ibu      25149 non-null  float64
#  36  B4K7THN_ibu   25149 non-null  float64
#  37  B4K8_ibu      25149 non-null  float64
#  38  B4K9_ibu      25149 non-null  float64
#  39  B4K10_ibu     25149 non-null  float64
#  40  B4K11_ibu     25149 non-null  float64
#  41  B4K1_KK       25800 non-null  int64
#  42  B4K3_KK       25800 non-null  int64
#  43  B4K4_KK       25800 non-null  int64
#  44  B4K5_KK       25800 non-null  int64
#  45  B4K7KD        25800 non-null  int64
#  46  B4K7THN_KK    25800 non-null  int64
#  47  B4K8_KK       25800 non-null  int64
#  48  B4K9_KK       25800 non-null  int64
#  49  B4K10_KK      25800 non-null  int64
#  50  B4K11_KK      25800 non-null  int64
#  51  B4K1_ayah     24255 non-null  float64
#  52  B4K3_ayah     24255 non-null  float64
#  53  B4K4_ayah     24255 non-null  float64
#  54  B4K5_ayah     24255 non-null  float64
#  55  B4K7THN_ayah  24255 non-null  float64
#  56  B4K8_ayah     24255 non-null  float64
#  57  B4K9_ayah     24255 non-null  float64
#  58  B4K10_ayah    24255 non-null  float64
#  59  B4K11_ayah    24255 non-null  float64
#  60  HAZ           25800 non-null  object
#  61  WAZ           25800 non-null  object
#  62  WHZ           25800 non-null  object
#  63  stunting      25800 non-null  object
#  64  underweight   25800 non-null  object
#  65  wasting       25800 non-null  object
#  66  overweight    25800 non-null  object
# dtypes: float64(25), int64(23), object(19)
# memory usage: 13.2+ MB

# %%
# Display a description of the dataset file
df.describe()
# Out:
#                IDRT          IDART           PSU        STRATA     B1R1  \
# count   25800.00000   25800.000000  25800.000000  25800.000000  25800.0
# mean   126562.86845  155841.414767  14015.216822  33234.409884     33.0
# std      7189.24325   91307.257606    760.509036    220.657284      0.0
# min    114171.00000     109.000000  12722.000000  33011.000000     33.0
# 25%    120333.50000   75801.500000  13352.000000  33091.000000     33.0
# 50%    126497.50000  156041.500000  14004.000000  33172.000000     33.0
# 75%    132867.25000  235017.250000  14675.250000  33261.000000     33.0
# max    138967.00000  314120.000000  15357.000000  33761.000000     33.0
#
#             provkab          B1R5          NART          B4K3          B4K4  \
# count  25800.000000  25800.000000  25798.000000  25800.000000  25800.000000
# mean    3323.315775      1.252132      4.173037      3.373256      1.485543
# std       22.075928      0.434245      1.061937      1.048155      0.499801
# min     3301.000000      1.000000      2.000000      3.000000      1.000000
# 25%     3309.000000      1.000000      3.000000      3.000000      1.000000
# 50%     3317.000000      1.000000      4.000000      3.000000      1.000000
# 75%     3326.000000      2.000000      5.000000      3.000000      2.000000
# max     3376.000000      2.000000     14.000000     10.000000      2.000000
#
#        ...      B4K11_KK     B4K1_ayah     B4K3_ayah  B4K4_ayah     B4K5_ayah  \
# count  ...  25800.000000  24255.000000  24255.000000    24255.0  24255.000000
# mean   ...      9.532519      1.261266      1.339435        1.0      2.003834
# std    ...     13.402644      0.848151      1.092649        0.0      0.092749
# min    ...     -1.000000      1.000000      1.000000        1.0      0.000000
# 25%    ...      1.000000      1.000000      1.000000        1.0      2.000000
# 50%    ...      2.000000      1.000000      1.000000        1.0      2.000000
# 75%    ...     32.000000      1.000000      1.000000        1.0      2.000000
# max    ...     32.000000     11.000000     10.000000        1.0      4.000000
#
#        B4K7THN_ayah     B4K8_ayah     B4K9_ayah  B4K10_ayah    B4K11_ayah
# count  24255.000000  24255.000000  24255.000000     24255.0  24255.000000
# mean      36.032612      4.496228      5.403628         0.0      9.650423
# std        7.178419      1.188359      1.677716         0.0     14.562846
# min       16.000000      1.000000      1.000000         0.0     -1.000000
# 25%       31.000000      4.000000      4.000000         0.0      1.000000
# 50%       35.000000      5.000000      5.000000         0.0      2.000000
# 75%       40.000000      5.000000      6.000000         0.0     32.000000
# max      146.000000      7.000000      9.000000         0.0    888.000000
#
# [8 rows x 48 columns]

# %% [markdown]
# ##**2.1 Data Distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display visualisations for each attribute
for atribut in df.columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(data=df, x=atribut)
    plt.title('Data Distribution of Attributes: {}'.format(atribut))
    plt.xlabel('Value')
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# ##**2.2 Daerah dan Stuntingnya**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter data untuk hanya memasukkan baris dengan status stunting (1)
df_stunting = df[df['stunting'] == '1,00']

# Group data berdasarkan kabupaten dan hitung jumlah stunting di tiap kabupaten
df_grouped = df_stunting.groupby('KBTEKS')['stunting'].count().reset_index()

# Urutkan data berdasarkan jumlah stunting dalam urutan menurun
df_grouped = df_grouped.sort_values(by='stunting', ascending=False)

# Buat bar chart untuk visualisasi
plt.figure(figsize=(15, 6))
bars=plt.bar(df_grouped['KBTEKS'], df_grouped['stunting'])
plt.title('Kabupaten dan Jumlah Stuntingnya')
plt.xlabel('Kabupaten')
plt.ylabel('Jumlah Stunting')
plt.xticks(rotation=90)
plt.tight_layout()
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + .05,
             round(yval,2), ha='center', va='bottom')
plt.show()

# %% [markdown]
# # **3. CLEANING DATA**

# %% [markdown]
# ## **3.1 Cek Missing Value**

# %%
df.isnull().sum()
# Out:
# IDRT           0
# IDART          0
# W_ruta         0
# W_balita       0
# PSU            0
#               ..
# WHZ            0
# stunting       0
# underweight    0
# wasting        0
# overweight     0
# Length: 67, dtype: int64

# %%
nan_count = df.isnull().sum().reset_index(name='nan')
data_types = df.dtypes.reset_index(name='dtype')

result = pd.merge(nan_count, data_types, on='index')
result
# Out:
#           index  nan   dtype
# 0          IDRT    0   int64
# 1         IDART    0   int64
# 2        W_ruta    0  object
# 3      W_balita    0  object
# 4           PSU    0   int64
# ..          ...  ...     ...
# 62          WHZ    0  object
# 63     stunting    0  object
# 64  underweight    0  object
# 65      wasting    0  object
# 66   overweight    0  object
#
# [67 rows x 3 columns]

# %% [markdown]
# ## **3.2 Cek Duplicate Value**

# %%
# Displaying duplicate data
duplicate_rows = df.duplicated()
print("All Duplicate Rows:")
df[df.duplicated(keep=False)]
# Out:
# All Duplicate Rows:
# Empty DataFrame
# Columns: [IDRT, IDART, W_ruta, W_balita, PSU, STRATA, B1R1, provkab, B1R5, NART, PTEKS, KBTEKS, B4K3, B4K4, b4k7hr, b4k7bln, I01, I04, BB8R3, I05A, I05B, I07, I08, I09, I10, BB8R9, J01A, J01B, J01C, J02A, J02B, J02C, B4K1_ibu, B4K3_ibu, B4K4_ibu, B4K5_ibu, B4K7THN_ibu, B4K8_ibu, B4K9_ibu, B4K10_ibu, B4K11_ibu, B4K1_KK, B4K3_KK, B4K4_KK, B4K5_KK, B4K7KD, B4K7THN_KK, B4K8_KK, B4K9_KK, B4K10_KK, B4K11_KK, B4K1_ayah, B4K3_ayah, B4K4_ayah, B4K5_ayah, B4K7THN_ayah, B4K8_ayah, B4K9_ayah, B4K10_ayah, B4K11_ayah, HAZ, WAZ, WHZ, stunting, underweight, wasting, overweight]
# Index: []
#
# [0 rows x 67 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25800 entries, 0 to 25799
# Data columns (total 67 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   IDRT          25800 non-null  int64
#  1   IDART         25800 non-null  int64
#  2   W_ruta        25800 non-null  object
#  3   W_balita      25800 non-null  object
#  4   PSU           25800 non-null  int64
#  5   STRATA        25800 non-null  int64
#  6   B1R1          25800 non-null  int64
#  7   provkab       25800 non-null  int64
#  8   B1R5          25800 non-null  int64
#  9   NART          25798 non-null  float64
#  10  PTEKS         25800 non-null  object
#  11  KBTEKS        25800 non-null  object
#  12  B4K3          25800 non-null  int64
#  13  B4K4          25800 non-null  int64
#  14  b4k7hr        25800 non-null  int64
#  15  b4k7bln       25800 non-null  int64
#  16  I01           25792 non-null  float64
#  17  I04           25349 non-null  float64
#  18  BB8R3         19423 non-null  object
#  19  I05A          25568 non-null  object
#  20  I05B          25560 non-null  object
#  21  I07           25800 non-null  object
#  22  I08           24101 non-null  object
#  23  I09           5960 non-null   float64
#  24  I10           23436 non-null  object
#  25  BB8R9         16914 non-null  float64
#  26  J01A          25798 non-null  float64
#  27  J01B          25794 non-null  float64
#  28  J01C          25800 non-null  object
#  29  J02A          25800 non-null  int64
#  30  J02B          25800 non-null  object
#  31  J02C          25800 non-null  int64
#  32  B4K1_ibu      25149 non-null  float64
#  33  B4K3_ibu      25149 non-null  float64
#  34  B4K4_ibu      25149 non-null  float64
#  35  B4K5_ibu      25149 non-null  float64
#  36  B4K7THN_ibu   25149 non-null  float64
#  37  B4K8_ibu      25149 non-null  float64
#  38  B4K9_ibu      25149 non-null  float64
#  39  B4K10_ibu     25149 non-null  float64
#  40  B4K11_ibu     25149 non-null  float64
#  41  B4K1_KK       25800 non-null  int64
#  42  B4K3_KK       25800 non-null  int64
#  43  B4K4_KK       25800 non-null  int64
#  44  B4K5_KK       25800 non-null  int64
#  45  B4K7KD        25800 non-null  int64
#  46  B4K7THN_KK    25800 non-null  int64
#  47  B4K8_KK       25800 non-null  int64
#  48  B4K9_KK       25800 non-null  int64
#  49  B4K10_KK      25800 non-null  int64
#  50  B4K11_KK      25800 non-null  int64
#  51  B4K1_ayah     24255 non-null  float64
#  52  B4K3_ayah     24255 non-null  float64
#  53  B4K4_ayah     24255 non-null  float64
#  54  B4K5_ayah     24255 non-null  float64
#  55  B4K7THN_ayah  24255 non-null  float64
#  56  B4K8_ayah     24255 non-null  float64
#  57  B4K9_ayah     24255 non-null  float64
#  58  B4K10_ayah    24255 non-null  float64
#  59  B4K11_ayah    24255 non-null  float64
#  60  HAZ           25800 non-null  object
#  61  WAZ           25800 non-null  object
#  62  WHZ           25800 non-null  object
#  63  stunting      25800 non-null  object
#  64  underweight   25800 non-null  object
#  65  wasting       25800 non-null  object
#  66  overweight    25800 non-null  object
# dtypes: float64(25), int64(23), object(19)
# memory usage: 13.2+ MB

# %% [markdown]
# ## **3.3Hapus Kolom yang tidak perlu**

# %%
df.drop(['IDRT','IDART','W_ruta','W_balita','PSU','STRATA','B1R1','provkab','B1R5','NART','PTEKS','KBTEKS','B4K3','b4k7hr','b4k7bln','I01','BB8R3','I05B','I08','I09','BB8R9','J01A','J02A','B4K1_ibu','B4K3_ibu','B4K4_ibu','B4K7THN_ibu','B4K1_KK','B4K3_KK','B4K4_KK','B4K5_KK','B4K7KD','B4K7THN_KK','B4K10_KK','B4K11_KK','B4K1_ayah','B4K3_ayah','B4K4_ayah','B4K5_ayah','B4K7THN_ayah','B4K8_ayah','B4K9_ayah','B4K10_ayah','B4K11_ayah','HAZ','WAZ','WHZ'], axis=1, inplace=True)

# %%
dataClean = df
print(dataClean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25800 entries, 0 to 25799
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   B4K4         25800 non-null  int64
#  1   I04          25349 non-null  float64
#  2   I05A         25568 non-null  object
#  3   I07          25800 non-null  object
#  4   I10          23436 non-null  object
#  5   J01B         25794 non-null  float64
#  6   J01C         25800 non-null  object
#  7   J02B         25800 non-null  object
#  8   J02C         25800 non-null  int64
#  9   B4K5_ibu     25149 non-null  float64
#  10  B4K8_ibu     25149 non-null  float64
#  11  B4K9_ibu     25149 non-null  float64
#  12  B4K10_ibu    25149 non-null  float64
#  13  B4K11_ibu    25149 non-null  float64
#  14  B4K8_KK      25800 non-null  int64
#  15  B4K9_KK      25800 non-null  int64
#  16  stunting     25800 non-null  object
#  17  underweight  25800 non-null  object
#  18  wasting      25800 non-null  object
#  19  overweight   25800 non-null  object
# dtypes: float64(7), int64(4), object(9)
# memory usage: 3.9+ MB
# None

# %% [markdown]
# ## **3.4 Hapus Missing Value**

# %%
dataClean.dropna(inplace=True)

# %%
dataClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22399 entries, 1 to 25799
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   B4K4         22399 non-null  int64
#  1   I04          22399 non-null  float64
#  2   I05A         22399 non-null  object
#  3   I07          22399 non-null  object
#  4   I10          22399 non-null  object
#  5   J01B         22399 non-null  float64
#  6   J01C         22399 non-null  object
#  7   J02B         22399 non-null  object
#  8   J02C         22399 non-null  int64
#  9   B4K5_ibu     22399 non-null  float64
#  10  B4K8_ibu     22399 non-null  float64
#  11  B4K9_ibu     22399 non-null  float64
#  12  B4K10_ibu    22399 non-null  float64
#  13  B4K11_ibu    22399 non-null  float64
#  14  B4K8_KK      22399 non-null  int64
#  15  B4K9_KK      22399 non-null  int64
#  16  stunting     22399 non-null  object
#  17  underweight  22399 non-null  object
#  18  wasting      22399 non-null  object
#  19  overweight   22399 non-null  object
# dtypes: float64(7), int64(4), object(9)
# memory usage: 3.6+ MB

# %% [markdown]
# #**4. ENCODING**

# %% [markdown]
# ## **4.1 Mengubah Tipe Data Object ke Numeric**

# %%
from sklearn.preprocessing import LabelEncoder

# Buat objek LabelEncoder
le = LabelEncoder()

# Ubah tipe data kolom 'I05A' menjadi angka
dataClean['I05A'] = le.fit_transform(df['I05A'])

# Ubah tipe data kolom 'I07' menjadi angka
dataClean['I07'] = le.fit_transform(df['I07'])

# Ubah tipe data kolom 'I10' menjadi angka
dataClean['I10'] = le.fit_transform(df['I10'])

# Ubah tipe data kolom 'J01C' menjadi angka
dataClean['J01C'] = le.fit_transform(df['J01C'])

# Ubah tipe data kolom 'J02B' menjadi angka
dataClean['J02B'] = le.fit_transform(df['J02B'])

# Ubah tipe data kolom 'J02B' menjadi angka
dataClean['stunting'] = le.fit_transform(df['stunting'])

# Ubah tipe data kolom 'J02B' menjadi angka
dataClean['underweight'] = le.fit_transform(df['underweight'])

# Ubah tipe data kolom 'J02B' menjadi angka
dataClean['wasting'] = le.fit_transform(df['wasting'])

# Ubah tipe data kolom 'J02B' menjadi angka
dataClean['overweight'] = le.fit_transform(df['overweight'])

# %%
dataClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22399 entries, 1 to 25799
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   B4K4         22399 non-null  int64
#  1   I04          22399 non-null  float64
#  2   I05A         22399 non-null  int64
#  3   I07          22399 non-null  int64
#  4   I10          22399 non-null  int64
#  5   J01B         22399 non-null  float64
#  6   J01C         22399 non-null  int64
#  7   J02B         22399 non-null  int64
#  8   J02C         22399 non-null  int64
#  9   B4K5_ibu     22399 non-null  float64
#  10  B4K8_ibu     22399 non-null  float64
#  11  B4K9_ibu     22399 non-null  float64
#  12  B4K10_ibu    22399 non-null  float64
#  13  B4K11_ibu    22399 non-null  float64
#  14  B4K8_KK      22399 non-null  int64
#  15  B4K9_KK      22399 non-null  int64
#  16  stunting     22399 non-null  int64
#  17  underweight  22399 non-null  int64
#  18  wasting      22399 non-null  int64
#  19  overweight   22399 non-null  int64
# dtypes: float64(7), int64(13)
# memory usage: 3.6 MB

# %% [markdown]
# ## **4.2 Korelasi Antar Fitur**

# %%
dataClean.corr()
# Out:
#                  B4K4       I04      I05A       I07       I10      J01B  \
# B4K4         1.000000  0.014189 -0.098973 -0.088644 -0.031586 -0.012737
# I04          0.014189  1.000000  0.264192  0.144996 -0.009185 -0.003066
# I05A        -0.098973  0.264192  1.000000  0.451274  0.116496 -0.004576
# I07         -0.088644  0.144996  0.451274  1.000000  0.270746 -0.006839
# I04          -0.000976   0.005083 -0.002172  0.011054  0.034763     0.041565
# I05A          0.005113   0.008729  0.025106 -0.015903  0.157984     0.175321
# I07          -0.004588   0.017228  0.005700 -0.015922  0.112735     0.097053
# I10           0.003602  -0.005494  0.037055 -0.032495  0.022798     0.034762
# J01B          0.007475  -0.007722  0.005049  0.023372 -0.025020    -0.048555
# J01C          0.030149  -0.027422 -0.008648  0.002733 -0.014952    -0.051309
# J02B          0.012851   0.018640 -0.024036  0.015770 -0.164936    -0.127910
# J02C          0.047107  -0.018172 -0.036910  0.007769  0.041160     0.060645
# B4K5_ibu      0.009702   0.000209 -0.011447 -0.010174  0.000567     0.003429
# B4K8_ibu     -0.023536  -0.102139  0.591392 -0.246152  0.085573     0.067081
# B4K9_ibu      0.008288  -0.009175  0.043221  0.039440 -0.005059     0.004514
# B4K10_ibu     1.000000   0.014907 -0.015981 -0.007967 -0.002929     0.004774
# B4K11_ibu     0.014907   1.000000 -0.103827  0.039235 -0.015872    -0.016490
# B4K8_KK      -0.015981  -0.103827  1.000000 -0.318503  0.068687     0.044597
# B4K9_KK      -0.007967   0.039235 -0.318503  1.000000 -0.055724    -0.040512
# stunting     -0.002929  -0.015872  0.068687 -0.055724  1.000000     0.448326
# underweight   0.004774  -0.016490  0.044597 -0.040512  0.448326     1.000000
# wasting       0.003388  -0.006219  0.023781 -0.015435  0.036367     0.415268
# overweight   -0.002694   0.024837 -0.035294  0.029403  0.014856    -0.085284
#
#               wasting  overweight
# B4K4         0.023898    0.033176
# I04          0.027833   -0.008322
# I05A         0.090770   -0.038444
# I07          0.028066   -0.013119
# I10          0.030370   -0.017674
# J01B        -0.023117    0.020815
# J01C        -0.065432   -0.035409
# J02B        -0.001668    0.088551
# J02C         0.004266   -0.004654
# B4K5_ibu     0.016191   -0.013716
# B4K8_ibu     0.029944   -0.042867
# B4K9_ibu    -0.005948   -0.012869
# B4K10_ibu    0.003388   -0.002694
# B4K11_ibu   -0.006219    0.024837
# B4K8_KK      0.023781   -0.035294
# B4K9_KK     -0.015435    0.029403
# stunting     0.036367    0.014856
# underweight  0.415268   -0.085284
# wasting      1.000000   -0.061427
# overweight  -0.061427    1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Correlation matrix
plt.figure(figsize=(12, 8))
correlation_matrix = dataClean.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Adjust the layout to accommodate the number of columns in your dataset
dataClean.plot(kind='box', subplots=True, layout=(8,6), sharex=False, figsize=(20, 20),
        title='Data distributions of all features')
plt.show()

# %% [markdown]
# # **5. DATA CONSTRUCTION**

# %%
dataClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22399 entries, 1 to 25799
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   B4K4         22399 non-null  int64
#  1   I04          22399 non-null  float64
#  2   I05A         22399 non-null  int64
#  3   I07          22399 non-null  int64
#  4   I10          22399 non-null  int64
#  5   J01B         22399 non-null  float64
#  6   J01C         22399 non-null  int64
#  7   J02B         22399 non-null  int64
#  8   J02C         22399 non-null  int64
#  9   B4K5_ibu     22399 non-null  float64
#  10  B4K8_ibu     22399 non-null  float64
#  11  B4K9_ibu     22399 non-null  float64
#  12  B4K10_ibu    22399 non-null  float64
#  13  B4K11_ibu    22399 non-null  float64
#  14  B4K8_KK      22399 non-null  int64
#  15  B4K9_KK      22399 non-null  int64
#  16  stunting     22399 non-null  int64
#  17  underweight  22399 non-null  int64
#  18  wasting      22399 non-null  int64
#  19  overweight   22399 non-null  int64
# dtypes: float64(7), int64(13)
# memory usage: 3.6 MB

# %% [markdown]
# ## **5.1 Data Oversampling with SMOTE**

# %%
X = dataClean.drop('stunting', axis=1)  # Features
y = dataClean['stunting']

# %%
# Distribution Target Feature

sns.countplot(x='stunting', data=dataClean)
plt.title('Distribution of Stunting Counts')
plt.xlabel('Stunting Status')
plt.ylabel('Count')
plt.show()

counts = dataClean['stunting'].value_counts()

print("Count of each unique value in 'counts':")
print(counts)
# Out:
# Count of each unique value in 'counts':
# stunting
# 1    17970
# 0     4429
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# Oversampling
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
plt.figure(figsize=(12, 4))

new_df1 = pd.DataFrame(data=y)

plt.subplot(1, 2, 1)
new_df1.value_counts().plot(kind='bar',figsize=(10,6),color=['blue'])
plt.title("target before over sampling with SMOTE ")
plt.xticks(rotation=0);


plt.subplot(1, 2, 2)
new_df2 = pd.DataFrame(data=y_resampled)


new_df2.value_counts().plot(kind='bar',figsize=(10,6),color=['blue'])
plt.title("target after over sampling with SMOTE")
plt.xticks(rotation=0);

plt.tight_layout()
plt.show()

# %% [markdown]
# ##**5.2 Normalization with StandardScaler**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.utils import resample
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_resampled_normal = scaler.fit_transform(X_resampled)

# %% [markdown]
# #**6. Data Splitting**

# %%
from sklearn.model_selection import train_test_split

# %%
# Membagi fitur dan target menjadi data train dan test (untuk yang oversample saja)
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42,stratify=y_resampled)

# %%
# Split features and targets into train and test data (for oversample + Normalization)
X_train_normal, X_test_normal, y_train_normal, y_test_normal = train_test_split(X_resampled_normal, y_resampled, test_size=0.2, random_state=42,stratify=y_resampled)

# %% [markdown]
# #**7. MODELLING**

# %% [markdown]
# ##**7.1 Modelling for SMOTE + Tuning**

# %%
pip install scikeras
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.4.1)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler

# %%
# Define the model
def create_model(optimizer='adam', dropout_rate=0.0):
    model = Sequential()
    model.add(Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dropout(dropout_rate))  # Dropout for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(dropout_rate))  # Dropout for regularization
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Wrap the model with KerasClassifier for GridSearch
model = KerasClassifier(model=create_model, verbose=0)

# Define hyperparameters to tune
param_grid = {
    'batch_size': [32, 64],
    'epochs': [100, 200],
    'optimizer': ['adam', 'rmsprop']
}

# Grid Search for hyperparameter tuning
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search_result = grid_search.fit(X_train, y_train)

# Output best parameters
print("Best Hyperparameters: ", grid_search_result.best_params_)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Best Hyperparameters:  {'batch_size': 32, 'epochs': 200, 'optimizer': 'adam'}

# %%
# Define learning rate scheduler function
def lr_scheduler(epoch, lr):
    if epoch > 50:
        return lr * 0.9  # Reduce learning rate by 10% after 50 epochs
    return lr

# Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Learning Rate Scheduler
lr_scheduler_callback = LearningRateScheduler(lr_scheduler)

# Mendapatkan model terbaik setelah GridSearchCV
best_model = grid_search.best_estimator_

# Pelatihan ulang dengan best_model
history = best_model.fit(X_train, y_train,
                         epochs=grid_search_result.best_params_['epochs'],
                         batch_size=grid_search_result.best_params_['batch_size'],
                         validation_data=(X_test, y_test),
                         callbacks=[early_stopping, lr_scheduler_callback],
                         verbose=2)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 899/899 - 3s - 3ms/step - accuracy: 0.6119 - loss: 0.9129 - val_accuracy: 0.6258 - val_loss: 0.9920
# Epoch 2/200
# 899/899 - 2s - 3ms/step - accuracy: 0.6453 - loss: 0.6461 - val_accuracy: 0.6928 - val_loss: 0.5650
# Epoch 3/200
# 899/899 - 3s - 3ms/step - accuracy: 0.6756 - loss: 0.5873 - val_accuracy: 0.7158 - val_loss: 0.5462
# Epoch 4/200
# 899/899 - 3s - 4ms/step - accuracy: 0.7029 - loss: 0.5477 - val_accuracy: 0.7667 - val_loss: 0.4841
# Epoch 5/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7277 - loss: 0.5200 - val_accuracy: 0.7529 - val_loss: 0.4767
# Epoch 6/200
# 899/899 - 2s - 3ms/step - accuracy: 0.7384 - loss: 0.5031 - val_accuracy: 0.7660 - val_loss: 0.4754
# Epoch 7/200
# 899/899 - 1s - 2ms/step - accuracy: 0.7504 - loss: 0.4870 - val_accuracy: 0.7625 - val_loss: 0.4794
# Epoch 8/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7575 - loss: 0.4750 - val_accuracy: 0.7766 - val_loss: 0.4441
# Epoch 9/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7675 - loss: 0.4590 - val_accuracy: 0.7876 - val_loss: 0.4345
# Epoch 10/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7713 - loss: 0.4571 - val_accuracy: 0.7898 - val_loss: 0.4331
# Epoch 11/200
# 899/899 - 1s - 2ms/step - accuracy: 0.7709 - loss: 0.4555 - val_accuracy: 0.7798 - val_loss: 0.4273
# Epoch 12/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7786 - loss: 0.4463 - val_accuracy: 0.7942 - val_loss: 0.4317
# Epoch 13/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7804 - loss: 0.4449 - val_accuracy: 0.7737 - val_loss: 0.4618
# Epoch 14/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7781 - loss: 0.4442 - val_accuracy: 0.7945 - val_loss: 0.4282
# Epoch 15/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7831 - loss: 0.4384 - val_accuracy: 0.8062 - val_loss: 0.4186
# Epoch 16/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7860 - loss: 0.4372 - val_accuracy: 0.7514 - val_loss: 0.4795
# Epoch 17/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7872 - loss: 0.4348 - val_accuracy: 0.8004 - val_loss: 0.4079
# Epoch 18/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7870 - loss: 0.4331 - val_accuracy: 0.8034 - val_loss: 0.4100
# Epoch 19/200
# 899/899 - 2s - 3ms/step - accuracy: 0.7849 - loss: 0.4355 - val_accuracy: 0.8058 - val_loss: 0.4087
# Epoch 20/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7877 - loss: 0.4307 - val_accuracy: 0.8061 - val_loss: 0.4034
# Epoch 21/200
# 899/899 - 3s - 4ms/step - accuracy: 0.7895 - loss: 0.4306 - val_accuracy: 0.7979 - val_loss: 0.4096
# Epoch 22/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7861 - loss: 0.4311 - val_accuracy: 0.7144 - val_loss: 0.5346
# Epoch 23/200
# 899/899 - 4s - 4ms/step - accuracy: 0.7895 - loss: 0.4276 - val_accuracy: 0.7664 - val_loss: 0.4647
# Epoch 24/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7888 - loss: 0.4300 - val_accuracy: 0.7980 - val_loss: 0.4091
# Epoch 25/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7926 - loss: 0.4256 - val_accuracy: 0.8005 - val_loss: 0.4071
# Epoch 26/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7915 - loss: 0.4236 - val_accuracy: 0.7952 - val_loss: 0.4105
# Epoch 27/200
# 899/899 - 2s - 3ms/step - accuracy: 0.7935 - loss: 0.4241 - val_accuracy: 0.8047 - val_loss: 0.4054
# Epoch 28/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7937 - loss: 0.4227 - val_accuracy: 0.7867 - val_loss: 0.4301
# Epoch 29/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7930 - loss: 0.4239 - val_accuracy: 0.7994 - val_loss: 0.4160
# Epoch 30/200
# 899/899 - 2s - 3ms/step - accuracy: 0.7949 - loss: 0.4202 - val_accuracy: 0.8040 - val_loss: 0.4038
# Epoch 31/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7964 - loss: 0.4218 - val_accuracy: 0.7883 - val_loss: 0.4323
# Epoch 32/200
# 899/899 - 4s - 4ms/step - accuracy: 0.7961 - loss: 0.4172 - val_accuracy: 0.8068 - val_loss: 0.4029
# Epoch 33/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7945 - loss: 0.4189 - val_accuracy: 0.7980 - val_loss: 0.4150
# Epoch 34/200
# 899/899 - 2s - 3ms/step - accuracy: 0.7970 - loss: 0.4191 - val_accuracy: 0.8079 - val_loss: 0.4093
# Epoch 35/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7965 - loss: 0.4212 - val_accuracy: 0.7912 - val_loss: 0.4213
# Epoch 36/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7928 - loss: 0.4203 - val_accuracy: 0.8079 - val_loss: 0.3987
# Epoch 37/200
# 899/899 - 1s - 2ms/step - accuracy: 0.7986 - loss: 0.4136 - val_accuracy: 0.7892 - val_loss: 0.4342
# Epoch 38/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7979 - loss: 0.4140 - val_accuracy: 0.8105 - val_loss: 0.3992
# Epoch 39/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7978 - loss: 0.4128 - val_accuracy: 0.7618 - val_loss: 0.4716
# Epoch 40/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7962 - loss: 0.4193 - val_accuracy: 0.8040 - val_loss: 0.4026
# Epoch 41/200
# 899/899 - 1s - 2ms/step - accuracy: 0.7975 - loss: 0.4193 - val_accuracy: 0.7984 - val_loss: 0.4163
# Epoch 42/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7992 - loss: 0.4135 - val_accuracy: 0.8026 - val_loss: 0.4030
# Epoch 43/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7983 - loss: 0.4141 - val_accuracy: 0.8088 - val_loss: 0.4013
# Epoch 44/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7992 - loss: 0.4135 - val_accuracy: 0.8098 - val_loss: 0.3983
# Epoch 45/200
# 899/899 - 3s - 3ms/step - accuracy: 0.7967 - loss: 0.4172 - val_accuracy: 0.8063 - val_loss: 0.4123
# Epoch 46/200
# 899/899 - 2s - 2ms/step - accuracy: 0.7994 - loss: 0.4098 - val_accuracy: 0.8075 - val_loss: 0.4012
# Epoch 47/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8034 - loss: 0.4096 - val_accuracy: 0.8023 - val_loss: 0.4013
# Epoch 48/200
# 899/899 - 1s - 2ms/step - accuracy: 0.7992 - loss: 0.4107 - val_accuracy: 0.8045 - val_loss: 0.4019
# Epoch 49/200
# 899/899 - 1s - 2ms/step - accuracy: 0.8037 - loss: 0.4084 - val_accuracy: 0.8097 - val_loss: 0.4001
# Epoch 50/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8010 - loss: 0.4106 - val_accuracy: 0.8132 - val_loss: 0.3996
# Epoch 51/200
# 899/899 - 4s - 4ms/step - accuracy: 0.8000 - loss: 0.4089 - val_accuracy: 0.8020 - val_loss: 0.3998
# Epoch 52/200
# 899/899 - 4s - 5ms/step - accuracy: 0.8036 - loss: 0.4073 - val_accuracy: 0.8006 - val_loss: 0.4131
# Epoch 53/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8043 - loss: 0.4075 - val_accuracy: 0.7831 - val_loss: 0.4354
# Epoch 54/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8045 - loss: 0.4058 - val_accuracy: 0.8086 - val_loss: 0.3958
# Epoch 55/200
# 899/899 - 4s - 4ms/step - accuracy: 0.
200
# 899/899 - 3s - 3ms/step - accuracy: 0.8123 - loss: 0.3897 - val_accuracy: 0.8180 - val_loss: 0.3816
# Epoch 120/200
# 899/899 - 4s - 4ms/step - accuracy: 0.8143 - loss: 0.3861 - val_accuracy: 0.8127 - val_loss: 0.4005
# Epoch 121/200
# 899/899 - 4s - 5ms/step - accuracy: 0.8173 - loss: 0.3844 - val_accuracy: 0.8093 - val_loss: 0.4094
# Epoch 122/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8190 - loss: 0.3836 - val_accuracy: 0.8166 - val_loss: 0.3901
# Epoch 123/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8125 - loss: 0.3876 - val_accuracy: 0.8141 - val_loss: 0.3919
# Epoch 124/200
# 899/899 - 4s - 4ms/step - accuracy: 0.8155 - loss: 0.3866 - val_accuracy: 0.7963 - val_loss: 0.4309
# Epoch 125/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8161 - loss: 0.3837 - val_accuracy: 0.8133 - val_loss: 0.3966
# Epoch 126/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8165 - loss: 0.3853 - val_accuracy: 0.8083 - val_loss: 0.3985
# Epoch 127/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8180 - loss: 0.3843 - val_accuracy: 0.8056 - val_loss: 0.3995
# Epoch 128/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8152 - loss: 0.3854 - val_accuracy: 0.8126 - val_loss: 0.3959
# Epoch 129/200
# 899/899 - 3s - 4ms/step - accuracy: 0.8179 - loss: 0.3839 - val_accuracy: 0.8161 - val_loss: 0.3842
# Epoch 130/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8150 - loss: 0.3844 - val_accuracy: 0.8018 - val_loss: 0.4019
# Epoch 131/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8143 - loss: 0.3837 - val_accuracy: 0.7999 - val_loss: 0.4130
# Epoch 132/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8151 - loss: 0.3846 - val_accuracy: 0.8134 - val_loss: 0.3953
# Epoch 133/200
# 899/899 - 1s - 2ms/step - accuracy: 0.8176 - loss: 0.3824 - val_accuracy: 0.8101 - val_loss: 0.3902
# Epoch 134/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8174 - loss: 0.3820 - val_accuracy: 0.8033 - val_loss: 0.4004
# Epoch 135/200
# 899/899 - 3s - 4ms/step - accuracy: 0.8161 - loss: 0.3857 - val_accuracy: 0.7891 - val_loss: 0.4267
# Epoch 136/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8171 - loss: 0.3838 - val_accuracy: 0.8175 - val_loss: 0.3911
# Epoch 137/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8164 - loss: 0.3837 - val_accuracy: 0.8101 - val_loss: 0.3937
# Epoch 138/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8163 - loss: 0.3838 - val_accuracy: 0.8194 - val_loss: 0.3912
# Epoch 139/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8166 - loss: 0.3836 - val_accuracy: 0.8165 - val_loss: 0.3877
# Epoch 140/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8207 - loss: 0.3804 - val_accuracy: 0.8183 - val_loss: 0.3866
# Epoch 141/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8166 - loss: 0.3831 - val_accuracy: 0.8204 - val_loss: 0.3834
# Epoch 142/200
# 899/899 - 4s - 5ms/step - accuracy: 0.8200 - loss: 0.3806 - val_accuracy: 0.8123 - val_loss: 0.3913
# Epoch 143/200
# 899/899 - 3s - 4ms/step - accuracy: 0.8185 - loss: 0.3813 - val_accuracy: 0.8027 - val_loss: 0.4023
# Epoch 144/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8184 - loss: 0.3821 - val_accuracy: 0.8165 - val_loss: 0.3878
# Epoch 145/200
# 899/899 - 3s - 4ms/step - accuracy: 0.8185 - loss: 0.3836 - val_accuracy: 0.8104 - val_loss: 0.3978
# Epoch 146/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8187 - loss: 0.3784 - val_accuracy: 0.8120 - val_loss: 0.3895
# Epoch 147/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8200 - loss: 0.3794 - val_accuracy: 0.8104 - val_loss: 0.3957
# Epoch 148/200
# 899/899 - 1s - 2ms/step - accuracy: 0.
200
# 899/899 - 3s - 3ms/step - accuracy: 0.8215 - loss: 0.3758 - val_accuracy: 0.8180 - val_loss: 0.3949
# Epoch 181/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8224 - loss: 0.3749 - val_accuracy: 0.8183 - val_loss: 0.3946
# Epoch 182/200
# 899/899 - 1s - 2ms/step - accuracy: 0.8220 - loss: 0.3748 - val_accuracy: 0.8178 - val_loss: 0.3922
# Epoch 183/200
# 899/899 - 1s - 2ms/step - accuracy: 0.8215 - loss: 0.3757 - val_accuracy: 0.8134 - val_loss: 0.3904
# Epoch 184/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8202 - loss: 0.3754 - val_accuracy: 0.7906 - val_loss: 0.4247
# Epoch 185/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8225 - loss: 0.3753 - val_accuracy: 0.8133 - val_loss: 0.3968
# Epoch 186/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8217 - loss: 0.3753 - val_accuracy: 0.8169 - val_loss: 0.3883
# Epoch 187/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8217 - loss: 0.3728 - val_accuracy: 0.8073 - val_loss: 0.3960
# Epoch 188/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8208 - loss: 0.3734 - val_accuracy: 0.8109 - val_loss: 0.4082
# Epoch 189/200
# 899/899 - 1s - 2ms/step - accuracy: 0.8226 - loss: 0.3752 - val_accuracy: 0.8173 - val_loss: 0.3838
# Epoch 190/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8237 - loss: 0.3737 - val_accuracy: 0.8084 - val_loss: 0.3996
# Epoch 191/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8211 - loss: 0.3739 - val_accuracy: 0.8102 - val_loss: 0.3981
# Epoch 192/200
# 899/899 - 4s - 5ms/step - accuracy: 0.8223 - loss: 0.3735 - val_accuracy: 0.8178 - val_loss: 0.3854
# Epoch 193/200
# 899/899 - 3s - 3ms/step - accuracy: 0.8221 - loss: 0.3741 - val_accuracy: 0.8084 - val_loss: 0.3950
# Epoch 194/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8255 - loss: 0.3701 - val_accuracy: 0.8159 - val_loss: 0.3976
# Epoch 195/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8232 - loss: 0.3727 - val_accuracy: 0.8176 - val_loss: 0.3949
# Epoch 196/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8234 - loss: 0.3726 - val_accuracy: 0.8169 - val_loss: 0.4001
# Epoch 197/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8217 - loss: 0.3720 - val_accuracy: 0.7941 - val_loss: 0.4221
# Epoch 198/200
# 899/899 - 2s - 3ms/step - accuracy: 0.8232 - loss: 0.3723 - val_accuracy: 0.8055 - val_loss: 0.4061
# Epoch 199/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8222 - loss: 0.3744 - val_accuracy: 0.8141 - val_loss: 0.3940
# Epoch 200/200
# 899/899 - 2s - 2ms/step - accuracy: 0.8227 - loss: 0.3706 - val_accuracy: 0.8205 - val_loss: 0.3890

# %%
# Predict on test data
y_pred = best_model.predict(X_test)
y_pred_class = (y_pred > 0.5).astype('int32')

# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred_class)
print(f"Optimized Model Accuracy: {accuracy}")
print(classification_report(y_test, y_pred_class))
# Out:
# Optimized Model Accuracy: 0.820534223706177
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81      3594
#            1       0.80      0.86      0.83      3594
#
#     accuracy                           0.82      7188
#    macro avg       0.82      0.82      0.82      7188
# weighted avg       0.82      0.82      0.82      7188

# %%
# Import library yang diperlukan
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Membuat confusion matrix
cm = confusion_matrix(y_test, y_pred_class)

# Membuat plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.xlabel('True')
plt.ylabel('Predict')
plt.show()

# %% [markdown]
# ##**7.2 Modelling SMOTE + Normalization + Tuning**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler

# %%
# Define the model
def create_model(optimizer='adam', dropout_rate=0.0):
    model = Sequential()
    model.add(Dense(128, activation='relu', input_shape=(X_train_normal.shape[1],)))
    model.add(Dropout(dropout_rate))  # Dropout for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(dropout_rate))  # Dropout for regularization
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Wrap the model with KerasClassifier for GridSearch
model = KerasClassifier(model=create_model, verbose=0)

# Define hyperparameters to tune
param_grid = {
    'batch_size': [32, 64],
    'epochs': [100, 200],
    'optimizer': ['adam', 'rmsprop']
}

# Grid Search for hyperparameter tuning
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search_result = grid_search.fit(X_train_normal, y_train_normal)

# Output best parameters
print("Best Hyperparameters: ", grid_search_result.best_params_)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits

# %%
# Define learning rate scheduler function
def lr_scheduler(epoch, lr):
    if epoch > 50:
        return lr * 0.9  # Reduce learning rate by 10% after 50 epochs
    return lr

# Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Learning Rate Scheduler
lr_scheduler_callback = LearningRateScheduler(lr_scheduler)

# Mendapatkan model terbaik setelah GridSearchCV
best_model = grid_search.best_estimator_

# Pelatihan ulang dengan best_model
history = best_model.fit(X_train_normal, y_train_normal,
                         epochs=grid_search_result.best_params_['epochs'],
                         batch_size=grid_search_result.best_params_['batch_size'],
                         validation_data=(X_test_normal, y_test_normal),
                         callbacks=[early_stopping, lr_scheduler_callback],
                         verbose=2)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 899/899 - 3s - 3ms/step - accuracy: 0.7727 - loss: 0.4653 - val_accuracy: 0.7905 - val_loss: 0.4298
# Epoch 2/100
# 899/899 - 3s - 4ms/step - accuracy: 0.7960 - loss: 0.4258 - val_accuracy: 0.7916 - val_loss: 0.4313
# Epoch 3/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8020 - loss: 0.4147 - val_accuracy: 0.7998 - val_loss: 0.4165
# Epoch 4/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8067 - loss: 0.4083 - val_accuracy: 0.8129 - val_loss: 0.3998
# Epoch 5/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8119 - loss: 0.4015 - val_accuracy: 0.8094 - val_loss: 0.4046
# Epoch 6/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8136 - loss: 0.3980 - val_accuracy: 0.8169 - val_loss: 0.3951
# Epoch 7/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8187 - loss: 0.3930 - val_accuracy: 0.8158 - val_loss: 0.3935
# Epoch 8/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8221 - loss: 0.3878 - val_accuracy: 0.8207 - val_loss: 0.3884
# Epoch 9/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8229 - loss: 0.3843 - val_accuracy: 0.8211 - val_loss: 0.3855
# Epoch 10/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8247 - loss: 0.3801 - val_accuracy: 0.8200 - val_loss: 0.3879
# Epoch 11/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8266 - loss: 0.3769 - val_accuracy: 0.8250 - val_loss: 0.3802
# Epoch 12/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8270 - loss: 0.3731 - val_accuracy: 0.8237 - val_loss: 0.3840
# Epoch 13/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8300 - loss: 0.3712 - val_accuracy: 0.8248 - val_loss: 0.3756
# Epoch 14/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8332 - loss: 0.3667 - val_accuracy: 0.8319 - val_loss: 0.3741
# Epoch 15/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8328 - loss: 0.3648 - val_accuracy: 0.8289 - val_loss: 0.3701
# Epoch 16/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8347 - loss: 0.3636 - val_accuracy: 0.8297 - val_loss: 0.3699
# Epoch 17/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8368 - loss: 0.3605 - val_accuracy: 0.8315 - val_loss: 0.3663
# Epoch 18/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8365 - loss: 0.3600 - val_accuracy: 0.8335 - val_loss: 0.3692
# Epoch 19/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8384 - loss: 0.3561 - val_accuracy: 0.8350 - val_loss: 0.3633
# Epoch 20/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8401 - loss: 0.3538 - val_accuracy: 0.8299 - val_loss: 0.3687
# Epoch 21/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8396 - loss: 0.3532 - val_accuracy: 0.8340 - val_loss: 0.3640
# Epoch 22/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8406 - loss: 0.3511 - val_accuracy: 0.8297 - val_loss: 0.3743
# Epoch 23/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8427 - loss: 0.3485 - val_accuracy: 0.8232 - val_loss: 0.3762
# Epoch 24/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8425 - loss: 0.3482 - val_accuracy: 0.8367 - val_loss: 0.3653
# Epoch 25/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8432 - loss: 0.3451 - val_accuracy: 0.8292 - val_loss: 0.3721
# Epoch 26/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8449 - loss: 0.3433 - val_accuracy: 0.8376 - val_loss: 0.3648
# Epoch 27/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8475 - loss: 0.3405 - val_accuracy: 0.8326 - val_loss: 0.3632
# Epoch 28/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8470 - loss: 0.3391 - val_accuracy: 0.8360 - val_loss: 0.3657
# Epoch 29/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8486 - loss: 0.3369 - val_accuracy: 0.8358 - val_loss: 0.3661
# Epoch 30/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8476 - loss: 0.3352 - val_accuracy: 0.8379 - val_loss: 0.3598
# Epoch 31/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8518 - loss: 0.3332 - val_accuracy: 0.8066 - val_loss: 0.4056
# Epoch 32/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8520 - loss: 0.3298 - val_accuracy: 0.8408 - val_loss: 0.3586
# Epoch 33/100
# 899/899 - 4s - 5ms/step - accuracy: 0.8521 - loss: 0.3291 - val_accuracy: 0.8375 - val_loss: 0.3637
# Epoch 34/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8532 - loss: 0.3262 - val_accuracy: 0.8432 - val_loss: 0.3558
# Epoch 35/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8545 - loss: 0.3257 - val_accuracy: 0.8374 - val_loss: 0.3627
# Epoch 36/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8541 - loss: 0.3234 - val_accuracy: 0.8432 - val_loss: 0.3598
# Epoch 37/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8576 - loss: 0.3204 - val_accuracy: 0.8379 - val_loss: 0.3579
# Epoch 38/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8572 - loss: 0.3191 - val_accuracy: 0.8457 - val_loss: 0.3528
# Epoch 39/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8590 - loss: 0.3164 - val_accuracy: 0.8403 - val_loss: 0.3604
# Epoch 40/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8588 - loss: 0.3150 - val_accuracy: 0.8389 - val_loss: 0.3593
# Epoch 41/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8595 - loss: 0.3128 - val_accuracy: 0.8400 - val_loss: 0.3572
# Epoch 42/100
# 899/899 - 3s - 4ms/step - accuracy: 0.8611 - loss: 0.3112 - val_accuracy: 0.8456 - val_loss: 0.3496
# Epoch 43/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8620 - loss: 0.3078 - val_accuracy: 0.8435 - val_loss: 0.3526
# Epoch 44/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8632 - loss: 0.3070 - val_accuracy: 0.8354 - val_loss: 0.3735
# Epoch 45/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8636 - loss: 0.3039 - val_accuracy: 0.8432 - val_loss: 0.3588
# Epoch 46/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8657 - loss: 0.3023 - val_accuracy: 0.8445 - val_loss: 0.3591
# Epoch 47/100
# 899/899 - 3s - 4ms/step - accuracy: 0.8660 - loss: 0.3007 - val_accuracy: 0.8417 - val_loss: 0.3689
# Epoch 48/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8664 - loss: 0.2984 - val_accuracy: 0.8365 - val_loss: 0.3620
# Epoch 49/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8669 - loss: 0.2965 - val_accuracy: 0.8414 - val_loss: 0.3722
# Epoch 50/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8693 - loss: 0.2947 - val_accuracy: 0.8408 - val_loss: 0.3638
# Epoch 51/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8689 - loss: 0.2931 - val_accuracy: 0.8443 - val_loss: 0.3577
# Epoch 52/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8708 - loss: 0.2897 - val_accuracy: 0.8350 - val_loss: 0.3728
# Epoch 53/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8700 - loss: 0.2891 - val_accuracy: 0.8470 - val_loss: 0.3559
# Epoch 54/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8731 - loss: 0.2856 - val_accuracy: 0.8447 - val_loss: 0.3588
# Epoch 55/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8733 - loss: 0.2864 - val_accuracy: 0.8479 - val_loss: 0.3568
# Epoch 56/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8736 - loss: 0.2845 - val_accuracy: 0.8450 - val_loss: 0.3626
# Epoch 57/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8761 - loss: 0.2804 - val_accuracy: 0.8502 - val_loss: 0.3613
# Epoch 58/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8763 - loss: 0.2806 - val_accuracy: 0.8463 - val_loss: 0.3599
# Epoch 59/100
# 899/899 - 4s - 4ms/step - accuracy: 0.8776 - loss: 0.2781 - val_accuracy: 0.8438 - val_loss: 0.3609
# Epoch 60/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8773 - loss: 0.2763 - val_accuracy: 0.8474 - val_loss: 0.3568
# Epoch 61/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8779 - loss: 0.2749 - val_accuracy: 0.8449 - val_loss: 0.3561
# Epoch 62/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8810 - loss: 0.2725 - val_accuracy: 0.8408 - val_loss: 0.3663
# Epoch 63/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8798 - loss: 0.2711 - val_accuracy: 0.8445 - val_loss: 0.3778
# Epoch 64/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8823 - loss: 0.2690 - val_accuracy: 0.8440 - val_loss: 0.3652
# Epoch 65/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8829 - loss: 0.2665 - val_accuracy: 0.8500 - val_loss: 0.3581
# Epoch 66/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8829 - loss: 0.2647 - val_accuracy: 0.8442 - val_loss: 0.3649
# Epoch 67/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8828 - loss: 0.2637 - val_accuracy: 0.8532 - val_loss: 0.3620
# Epoch 68/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8846 - loss: 0.2624 - val_accuracy: 0.8431 - val_loss: 0.3685
# Epoch 69/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8853 - loss: 0.2626 - val_accuracy: 0.8285 - val_loss: 0.3943
# Epoch 70/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8864 - loss: 0.2588 - val_accuracy: 0.8420 - val_loss: 0.3796
# Epoch 71/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8857 - loss: 0.2592 - val_accuracy: 0.8465 - val_loss: 0.3741
# Epoch 72/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8888 - loss: 0.2553 - val_accuracy: 0.8472 - val_loss: 0.3676
# Epoch 73/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8887 - loss: 0.2557 - val_accuracy: 0.8282 - val_loss: 0.4199
# Epoch 74/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8863 - loss: 0.2551 - val_accuracy: 0.8509 - val_loss: 0.3700
# Epoch 75/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8875 - loss: 0.2525 - val_accuracy: 0.8502 - val_loss: 0.3744
# Epoch 76/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8898 - loss: 0.2514 - val_accuracy: 0.8507 - val_loss: 0.3711
# Epoch 77/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8922 - loss: 0.2483 - val_accuracy: 0.8511 - val_loss: 0.3774
# Epoch 78/100
# 899/899 - 3s - 4ms/step - accuracy: 0.8896 - loss: 0.2478 - val_accuracy: 0.8502 - val_loss: 0.3829
# Epoch 79/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8930 - loss: 0.2456 - val_accuracy: 0.8460 - val_loss: 0.3928
# Epoch 80/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8912 - loss: 0.2480 - val_accuracy: 0.8484 - val_loss: 0.3801
# Epoch 81/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8938 - loss: 0.2408 - val_accuracy: 0.8468 - val_loss: 0.3875
# Epoch 82/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8940 - loss: 0.2414 - val_accuracy: 0.8525 - val_loss: 0.3818
# Epoch 83/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8943 - loss: 0.2416 - val_accuracy: 0.8507 - val_loss: 0.3839
# Epoch 84/100
# 899/899 - 4s - 4ms/step - accuracy: 0.8941 - loss: 0.2414 - val_accuracy: 0.8514 - val_loss: 0.3804
# Epoch 85/100
# 899/899 - 4s - 5ms/step - accuracy: 0.8960 - loss: 0.2383 - val_accuracy: 0.8502 - val_loss: 0.3882
# Epoch 86/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8965 - loss: 0.2368 - val_accuracy: 0.8429 - val_loss: 0.3952
# Epoch 87/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8961 - loss: 0.2353 - val_accuracy: 0.8518 - val_loss: 0.3881
# Epoch 88/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8974 - loss: 0.2340 - val_accuracy: 0.8463 - val_loss: 0.3884
# Epoch 89/100
# 899/899 - 3s - 3ms/step - accuracy: 0.8995 - loss: 0.2325 - val_accuracy: 0.8516 - val_loss: 0.3858
# Epoch 90/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8970 - loss: 0.2329 - val_accuracy: 0.8525 - val_loss: 0.3972
# Epoch 91/100
# 899/899 - 2s - 2ms/step - accuracy: 0.8983 - loss: 0.2310 - val_accuracy: 0.8516 - val_loss: 0.3836
# Epoch 92/100
# 899/899 - 2s - 2ms/step - accuracy: 0.9023 - loss: 0.2265 - val_accuracy: 0.8402 - val_loss: 0.3960
# Epoch 93/100
# 899/899 - 2s - 3ms/step - accuracy: 0.8999 - loss: 0.2306 - val_accuracy: 0.8531 - val_loss: 0.3955
# Epoch 94/100
# 899/899 - 2s - 2ms/step - accuracy: 0.9010 - loss: 0.2267 - val_accuracy: 0.8456 - val_loss: 0.4133
# Epoch 95/100
# 899/899 - 2s - 2ms/step - accuracy: 0.9011 - loss: 0.2269 - val_accuracy: 0.8425 - val_loss: 0.4239
# Epoch 96/100
# 899/899 - 2s - 3ms/step - accuracy: 0.9038 - loss: 0.2222 - val_accuracy: 0.8461 - val_loss: 0.4042
# Epoch 97/100
# 899/899 - 2s - 2ms/step - accuracy: 0.9005 - loss: 0.2233 - val_accuracy: 0.8518 - val_loss: 0.4166
# Epoch 98/100
# 899/899 - 2s - 3ms/step - accuracy: 0.9032 - loss: 0.2223 - val_accuracy: 0.8499 - val_loss: 0.4248
# Epoch 99/100
# 899/899 - 3s - 3ms/step - accuracy: 0.9052 - loss: 0.2213 - val_accuracy: 0.8513 - val_loss: 0.4170
# Epoch 100/100
# 899/899 - 3s - 3ms/step - accuracy: 0.9042 - loss: 0.2201 - val_accuracy: 0.8464 - val_loss: 0.4034

# %%
# Predict on test data
y_pred_normal = best_model.predict(X_test_normal)
y_pred_class_normal = (y_pred_normal > 0.5).astype('int32')

# Evaluate accuracy
accuracy = accuracy_score(y_test_normal, y_pred_class_normal)
print(f"Optimized Model Accuracy: {accuracy}")
print(classification_report(y_test_normal, y_pred_class_normal))
# Out:
# Optimized Model Accuracy: 0.8464106844741235
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85      3594
#            1       0.84      0.85      0.85      3594
#
#     accuracy                           0.85      7188
#    macro avg       0.85      0.85      0.85      7188
# weighted avg       0.85      0.85      0.85      7188

# %%
# Import library yang diperlukan
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Membuat confusion matrix
cm = confusion_matrix(y_test_normal, y_pred_class_normal)

# Membuat plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.xlabel('True')
plt.ylabel('Predict')
plt.show()
